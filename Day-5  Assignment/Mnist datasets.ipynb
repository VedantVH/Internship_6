# %%
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
import matplotlib.pyplot as plt
import numpy as np

# %%
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data()

train_images = train_images.reshape((60000, 28*28)).astype('float32') / 255.0
test_images = test_images.reshape((10000, 28*28)).astype('float32') / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
plt.figure(figsize=(10, 5))
for i in range(20):
    plt.subplot(4, 5, i + 1)
    plt.imshow(train_images[i].reshape(28, 28), cmap='gray')
    plt.title(f"Label: {train_labels[i]}")
    plt.axis('off')
plt.suptitle('Sample MNIST Images with Labels', y=1.02)
plt.tight_layout()
plt.show()

# %%
model = models.Sequential([
    layers.Dense(1024, activation='swish', kernel_regularizer=regularizers.l2(1e-4), input_shape=(784,)),
    layers.BatchNormalization(),
    layers.Dropout(0.4),

    layers.Dense(512, activation='swish', kernel_regularizer=regularizers.l2(1e-4)),
    layers.BatchNormalization(),
    layers.Dropout(0.3),

    layers.Dense(256, activation='swish', kernel_regularizer=regularizers.l2(1e-4)),
    layers.BatchNormalization(),
    layers.Dropout(0.1),

    layers.Dense(10, activation='softmax')
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
lr_schedule = ReduceLROnPlateau(
    monitor='val_accuracy', factor=0.5, patience=2, verbose=1
)

early_stop = EarlyStopping(
    monitor='val_accuracy', patience=5, restore_best_weights=True
)

# %%
history = model.fit(
    train_images, train_labels,
    epochs=75,
    batch_size=128,
    validation_data=(test_images, test_labels),
    callbacks=[lr_schedule, early_stop]
)
# Out:
# Epoch 1/75
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 29s 52ms/step - accuracy: 0.8843 - loss: 0.5510 - val_accuracy: 0.9651 - val_loss: 0.2693 - learning_rate: 0.0010
# Epoch 2/75
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 41s 53ms/step - accuracy: 0.9622 - loss: 0.2827 - val_accuracy: 0.9727 - val_loss: 0.2451 - learning_rate: 0.0010
# Epoch 3/75
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 25s 52ms/step - accuracy: 0.9684 - loss: 0.2509 - val_accuracy: 0.9769 - val_loss: 0.2166 - learning_rate: 0.0010
# Epoch 4/75
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 24s 52ms/step - accuracy: 0.9740 - loss: 0.2212 - val_accuracy: 0.9759 - val_loss: 0.2144 - learning_rate: 0.0010
# Epoch 5/75
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 40s 51ms/step - accuracy: 0.9757 - loss: 0.2097 - val_accuracy: 0.9785 - val_loss: 0.2018 - learning_rate: 0.0010
# Epoch 6/75
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 41s 51ms/step - accuracy: 0.9789 - loss: 0.1963 - val_accuracy: 0.9798 - val_loss: 0.1926 - learning_rate: 0.0010
# Epoch 7/75
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 24s 52ms/step - accuracy: 0.9805 - loss: 0.1870 - val_accuracy: 0.9780 - val_loss: 0.2019 - learning_rate: 0.0010
# Epoch 8/75
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9784 - loss: 0.1915
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 41s 51ms/step - accuracy: 0.9784 - loss: 0.1915 - val_accuracy: 0.9771 - val_loss: 0.1979 - learning_rate: 0.0010
# Epoch 9/75
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 41s 52ms/step - accuracy: 0.9862 - loss: 0.1687 - val_accuracy: 0.9838 - val_loss: 0.1644 - learning_rate: 5.0000e-04
# Epoch 10/75
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 39s 49ms/step - accuracy: 0.9891 - loss: 0.1423 - val_accuracy: 0.9829 - val_loss: 0.1571 - learning_rate: 5.0000e-04
# Epoch 11/75
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 42s 52ms/step - accuracy: 0.9876 - loss: 0.1361 - val_accuracy: 0.9841 - val_loss: 0.1481 - learning_rate: 5.0000e-04
# Epoch 12/75
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 40s 51ms/step - accuracy: 0.9883 - loss: 0.1283 - val_accuracy: 0.9799 - val_loss: 0.1595 - learning_rate: 5.0000e-04
# Epoch 13/75
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9878 - loss: 0.1259
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 42s 53ms/step - accuracy: 0.9878 - loss: 0.1259 - val_accuracy: 0.9840 - val_loss: 0.1439 - learning_rate: 5.0000e-04
# Epoch 14/75
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 24s 52ms/step - accuracy: 0.9914 - loss: 0.1138 - val_accuracy: 0.9868 - val_loss: 0.1254 - learning_rate: 2.5000e-04
# Epoch 15/75
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 40s 49ms/step - accuracy: 0.9935 - loss: 0.1025 - val_accuracy: 0.9861 - val_loss: 0.1232 - learning_rate: 2.5000e-04
# Epoch 16/75
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9944 - loss: 0.0938
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.9944 - loss: 0.0938 - val_accuracy: 0.9865 - val_loss: 0.1216 - learning_rate: 2.5000e-04
# Epoch 17/75
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 40s 50ms/step - accuracy: 0.9944 - loss: 0.0900 - val_accuracy: 0.9871 - val_loss: 0.1156 - learning_rate: 1.2500e-04
# Epoch 18/75
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 42s 52ms/step - accuracy: 0.9959 - loss: 0.0823 - val_accuracy: 0.9880 - val_loss: 0.1100 - learning_rate: 1.2500e-04
# Epoch 19/75
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 25s 53ms/step - accuracy: 0.9966 - loss: 0.0777 - val_accuracy: 0.9876 - val_loss: 0.1107 - learning_rate: 1.2500e-04
# Epoch 20/75
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9968 - loss: 0.0740
# Epoch 20: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 23s 49ms/step - accuracy: 0.9968 - loss: 0.0740 - val_accuracy: 0.9870 - val_loss: 0.1070 - learning_rate: 1.2500e-04
# Epoch 21/75
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 42s 52ms/step - accuracy: 0.9967 - loss: 0.0709 - val_accuracy: 0.9886 - val_loss: 0.1029 - learning_rate: 6.2500e-05
# Epoch 22/75
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 41s 52ms/step - accuracy: 0.9970 - loss: 0.0689 - val_accuracy: 0.9894 - val_loss: 0.0974 - learning_rate: 6.2500e-05
# Epoch 23/75
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 40s 51ms/step - accuracy: 0.9969 - loss: 0.0670 - val_accuracy: 0.9880 - val_loss: 0.1007 - learning_rate: 6.2500e-05
# Epoch 24/75
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9967 - loss: 0.0661
# Epoch 24: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 24s 52ms/step - accuracy: 0.9967 - loss: 0.0661 - val_accuracy: 0.9886 - val_loss: 0.0995 - learning_rate: 6.2500e-05
# Epoch 25/75
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 40s 49ms/step - accuracy: 0.9969 - loss: 0.0642 - val_accuracy: 0.9884 - val_loss: 0.0984 - learning_rate: 3.1250e-05
# Epoch 26/75
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9970 - loss: 0.0633
# Epoch 26: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.9970 - loss: 0.0633 - val_accuracy: 0.9890 - val_loss: 0.0954 - learning_rate: 3.1250e-05
# Epoch 27/75
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 24s 52ms/step - accuracy: 0.9976 - loss: 0.0611 - val_accuracy: 0.9890 - val_loss: 0.0956 - learning_rate: 1.5625e-05

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"\nTest accuracy: {test_acc:.4f}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9871 - loss: 0.1079
#
# Test accuracy: 0.9894

# %%
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# 10. Predict and visualize predictions
predictions = model.predict(test_images)
plt.figure(figsize=(10, 10))
for i in range(25):
    plt.subplot(5, 5, i + 1)
    plt.imshow(test_images[i].reshape(28, 28), cmap='gray')
    pred_label = np.argmax(predictions[i])
    true_label = test_labels[i]
    color = 'green' if pred_label == true_label else 'red'
    plt.title(f"Pred: {pred_label}\nTrue: {true_label}", color=color)
    plt.axis('off')
plt.suptitle('Model Predictions on Test Images', y=1.02)
plt.tight_layout()
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
